# %%
import streamlit as st
import pandas as pd
import webbrowser
from datetime import datetime

arquivo = r"C:\Users\vinil\OneDrive\Documents\ASIMOV ACADEMY PYTHON\Streamlit\Projeto Streamlit FIFA\datasets\CLEAN_FIFA23_official_data.csv"

df_data= pd.read_csv(arquivo,index_col=0)
df_data['Contract Valid Until']=df_data['Contract Valid Until'].apply(int)
hoje = datetime.today().year
df_data = df_data[df_data["Contract Valid Until"] >= hoje]
df_data = df_data[df_data["Value(£)"] > 0]
df_data = df_data.sort_values(by="Overall", ascending=False)

#df_data= df_data[df_data["Contract Valid Until"].dt.year >= hoje]

# %%
df_data
# Out:
#            ID             Name  Age  \
# 75     231747        K. Mbappé   23
# 41     188545   R. Lewandowski   33
# 3      192985     K. De Bruyne   31
# 192    203376      V. van Dijk   30
# 14357  192119      T. Courtois   30
# ...       ...              ...  ...
# 14624  268965   22 Zhang Yujun   19
# 14537  268963     Zhang Jiahui   19
# 15513  266751  22 Jung Ho Yeon   20
# 14353  269032    22 Chen Zeshi   16
# 16215  268279   22 J. Looschen   24
#
#                                                   Photo     Nationality  \
# 75     https://cdn.sofifa.net/players/231/747/23_60.png          France
# 41     https://cdn.sofifa.net/players/188/545/23_60.png          Poland
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 192    https://cdn.sofifa.net/players/203/376/23_60.png     Netherlands
# 14357  https://cdn.sofifa.net/players/192/119/23_60.png         Belgium
# ...                                                 ...             ...
# 14624  https://cdn.sofifa.net/players/268/965/22_60.png        China PR
# 14537  https://cdn.sofifa.net/players/268/963/23_60.png        China PR
# 15513  https://cdn.sofifa.net/players/266/751/22_60.png  Korea Republic
# 14353  https://cdn.sofifa.net/players/269/032/22_60.png        China PR
# 16215  https://cdn.sofifa.net/players/268/279/22_60.png         Germany
#
#                                       Flag  Overall  Potential  \
# 75     https://cdn.sofifa.net/flags/fr.png       91         95
# 41     https://cdn.sofifa.net/flags/pl.png       91         91
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 192    https://cdn.sofifa.net/flags/nl.png       90         90
# 14357  https://cdn.sofifa.net/flags/be.png       90         91
# ...                                    ...      ...        ...
# 14624  https://cdn.sofifa.net/flags/cn.png       46         56
# 14537  https://cdn.sofifa.net/flags/cn.png       46         55
# 15513  https://cdn.sofifa.net/flags/kr.png       45         53
# 14353  https://cdn.sofifa.net/flags/cn.png       45         55
# 16215  https://cdn.sofifa.net/flags/de.png       44         47
#
#                       Club                                   Club Logo  ...  \
# 75     Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# 41            FC Barcelona     https://cdn.sofifa.net/teams/241/30.png  ...
# 3          Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 192              Liverpool       https://cdn.sofifa.net/teams/9/30.png  ...
# 14357       Real Madrid CF     https://cdn.sofifa.net/teams/243/30.png  ...
# ...                    ...                                         ...  ...
# 14624             Hebei FC  https://cdn.sofifa.net/teams/112978/30.png  ...
# 14537             Hebei FC  https://cdn.sofifa.net/teams/112978/30.png  ...
# 15513           GwangJu FC  https://cdn.sofifa.net/teams/112258/30.png  ...
# 14353     Shandong Taishan  https://cdn.sofifa.net/teams/111724/30.png  ...
# 16215            SV Meppen  https://cdn.sofifa.net/teams/110597/30.png  ...
#
#        Position      Joined  Loaned From Contract Valid Until  Height(cm.)  \
# 75           ST  2018-07-01          NaN                 2025        182.0
# 41           ST  2022-07-18          NaN                 2025        185.0
# 3           RCM  2015-08-30          NaN                 2025        181.0
# 192         LCB  2018-01-01          NaN                 2025        193.0
# 14357        GK  2018-08-09          NaN                 2026        199.0
# ...         ...         ...          ...                  ...          ...
# 14624       RES  2022-04-30          NaN                 2026        176.0
# 14537       SUB  2022-04-30          NaN                 2027        182.0
# 15513       RES  2022-01-20          NaN                 2026        180.0
# 14353       RES  2022-05-01          NaN                 2024        180.0
# 16215       RES  2022-03-19          NaN                 2026        178.0
#
#        Weight(lbs.)  Release Clause(£) Kit Number Best Overall Rating  \
# 75          160.965        366700000.0        7.0                 0.0
# 41          178.605        172200000.0        9.0                 0.0
# 3           154.350        198900000.0       17.0                 0.0
# 192         202.860        181300000.0        4.0                 0.0
# 14357       211.680        191300000.0        1.0                 0.0
# ...             ...                ...        ...                 ...
# 14624       147.735           175000.0       28.0                 0.0
# 14537       152.145           175000.0       23.0                 0.0
# 15513       160.965           145000.0       23.0                 0.0
# 14353       154.350           175000.0       38.0                 0.0
# 16215       171.990            92000.0       42.0                 0.0
#
#       Year_Joined
# 75           2018
# 41           2022
# 3            2015
# 192          2018
# 14357        2018
# ...           ...
# 14624        2022
# 14537        2022
# 15513        2022
# 14353        2022
# 16215        2022
#
# [7484 rows x 30 columns]

# %%
type(hoje)
# Out:
# int

# %%
df_data['Contract Valid Until'].dt.year.unique()
# Out:
# array([1970])
